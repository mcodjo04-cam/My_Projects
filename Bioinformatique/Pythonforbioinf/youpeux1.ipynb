# %%
mydna="AGTCAGTA"
print(mydna)
# Out:
# AGTCAGTA

# %%
mydna.upper()

# %%
mydna.lower()
# Out:
# 'agtcagta'

# %%
'i' in mydna
'T' in mydna
mydna.count('T')
# Out:
# 2

# %%
at = mydna.count('T')+ mydna.count('A')
print(at)

mydna1 = mydna
re=mydna.replace('A','T')
re
# Out:
# 5
# 'TGTCTGTT'

# %%
first = "I love"
second = " Bioinformatics"
print(first + second)
full = "%s %s"  %(first ,second)
full
ful = f'{first} {second}'
ful
